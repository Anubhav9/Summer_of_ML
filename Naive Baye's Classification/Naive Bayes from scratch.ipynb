# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
dataset=pd.read_csv("C:/Users/Anubhav Sanyal/Desktop/Summer of ML-Coding Blocks/Naive Bayes Classification/mushrooms.csv")

# %%
dataset
# Out:
#      class cap-shape cap-surface cap-color bruises odor gill-attachment  \
# 0        p         x           s         n       t    p               f
# 1        e         x           s         y       t    a               f
# 2        e         b           s         w       t    l               f
# 3        p         x           y         w       t    p               f
# 4        e         x           s         g       f    n               f
# 5        e         x           y         y       t    a               f
# 6        e         b           s         w       t    a               f
# 7        e         b           y         w       t    l               f
# 8        p         x           y         w       t    p               f
# 9        e         b           s         y       t    a               f
# 10       e         x           y         y       t    l               f
# 11       e         x           y         y       t    a               f
# ...

# %%
from sklearn.preprocessing import LabelEncoder

# %%
lb=LabelEncoder()

# %%
dataset=dataset.apply(lb.fit_transform)

# %%
dataset
# Out:
#       class  cap-shape  cap-surface  cap-color  bruises  odor  \
# 0         1          5            2          4        1     6
# 1         0          5            2          9        1     0
# 2         0          0            2          8        1     3
# 3         1          5            3          8        1     6
# 4         0          5            2          3        0     5
# 5         0          5            3          9        1     0
# 6         0          0            2          8        1     0
# 7         0          0            3          8        1     3
# 8         1          5            3          8        1     6
# 9         0          0            2          9        1     0
# 10        0          5            3          9        1     3
# 11        0          5            3          9        1     0
# 12        0          0            2          9        1     0
# 13        1          5            3          8        1     6
# ...

# %%
X=dataset.iloc[:,1:]

# %%
X
# Out:
#       cap-shape  cap-surface  cap-color  bruises  odor  gill-attachment  \
# 0             5            2          4        1     6                1
# 1             5            2          9        1     0                1
# 2             0            2          8        1     3                1
# 3             5            3          8        1     6                1
# 4             5            2          3        0     5                1
# 5             5            3          9        1     0                1
# 6             0            2          8        1     0                1
# 7             0            3          8        1     3                1
# 8             5            3          8        1     6                1
# 9             0            2          9        1     0                1
# 10            5            3          9        1     3                1
# 11            5            3          9        1     0                1
# ...

# %%
y=dataset.iloc[:,0]

# %%
X=X.values

# %%
y=y.values

# %%
X.shape
# Out:
# (8124, 22)

# %%
y.shape
# Out:
# (8124,)

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.2,random_state=0)

# %%
def prior_prob(y_train,label):
    denominator=y_train.shape[0]
    numerator=np.sum(y_train==label)
    return (numerator)/float (denominator)

# %%
def conditional_prob(x_train,y_train,feature_col,feature_value,label):
    x_filtered=x_train[y_train==label]
    numerator=np.sum(x_filtered[:,feature_col]==feature_value)
    denominator=np.sum(y_train==label)
    return numerator/float(denominator)

# %%
X_train.shape[1]
# Out:
# 22

# %%
def prostorier_prob(X_train,y_train,point):
    final_prob=[]
    classes=np.unique(y_train)
    
    n_features=X_train.shape[1]
    
    for label in classes:
        likelihood=1.0
        for f in range (n_features):
            c=conditional_prob(X_train,y_train,f,point[f],label)
            likelihood=likelihood*c
        
        pr=prior_prob(y_train,label)
        post=pr*likelihood
        final_prob.append(post)
        print("final prob is", final_prob)
    max=np.argmax(final_prob)
    print('printnig the max',max)
    return max

# %%
conditional_prob(X_train,y_train,1,0,1)
# Out:
# 0.19376391982182628

# %%
#printing for  some test cases

for i in range(1200):
    t=prostorier_prob(X_train,y_train,X_test[i])
# Out:
# final prob is [0.0]
# final prob is [0.0, 1.8344429953101966e-12]
# printnig the max 1
# final prob is [1.2570260383723652e-07]
# final prob is [1.2570260383723652e-07, 0.0]
# printnig the max 0
# final prob is [4.301855963909949e-10]
# final prob is [4.301855963909949e-10, 0.0]
# printnig the max 0
# final prob is [6.2970757748057216e-09]
# final prob is [6.2970757748057216e-09, 0.0]
# printnig the max 0
# final prob is [1.0354482186604154e-06]
# final prob is [1.0354482186604154e-06, 5.371851684244285e-11]
# printnig the max 0
# final prob is [1.7808813180414754e-07]
# final prob is [1.7808813180414754e-07, 0.0]
# printnig the max 0
# final prob is [0.0]
# final prob is [0.0, 1.093406230251143e-12]
# printnig the max 1
# final prob is [0.0]
# final prob is [0.0, 7.261189239792441e-08]
# printnig the max 1
# final prob is [2.1023146893401005e-07]
# final prob is [2.1023146893401005e-07, 0.0]
# printnig the max 0
# final prob is [0.0]
# final prob is [0.0, 2.480420217670867e-08]
# ...

# %%
# Out:
# 1
